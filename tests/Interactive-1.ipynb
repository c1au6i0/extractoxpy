# %% [markdown]
# Connected to dev (Python 3.13.1)

# %%
# import pytest
import extractoxpy as extr

dat =  extr.extr_ice(casrn="50-00-0")

# def test_with_ice():
#     dat =  extr.extr_ice("50-00-0")
    
#     assert isinstance(dat, pd.DataFrame)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import ex
#
# ModuleNotFoundError: No module named 'ex'

# %%
import extractoxpy as extr

# %%
dat =  extr.extr_ice(casrn="50-00-0")

# %%
dat
# Out:
#                                                  assay  \
# 0                                        TER Corrosion
# 1    OPERA, soil adsorption coefficient of organic ...
# 2                                        TER Corrosion
# 3                          OPERA, Henry's Law Constant
# 4    OPERA, The whole body primary biotransformatio...
# ..                                                 ...
# 275                            Human Maximization Test
# 276                                             mMUSST
# 277                            Human Maximization Test
# 278                            Human Maximization Test
# 279                                             U-SENS
#
#                                               endpoint substance_type  \
# 0                                                 Call        Mixture
# 1                                 Applicability_Domain       Chemical
# 2                                                 Call        Mixture
# ...

# %%
import tabloo

# %%
tabloo.show(dat)
# Out:
#  * Serving Flask app 'tabloo.server'
#  * Debug mode: off
